# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# this has multiple features each assigned a different row for matrix dot product.
# %%time
weights = np.array([0.1, 2, 3])
x = np.array([
    [100, 200, 300, 400],
    [10, 20, 30, 40],
    [1, 2, 3, 4]
])

bias = 10

y = np.dot(weights, x) + bias
print(y)
# Out:
# [ 43.  76. 109. 142.]
# CPU times: total: 0 ns
# Wall time: 301 μs

# %%
# Same thing like minimizing the cost function for each set of weights is applied on multilinear regression
# using gradient descent to find the global minimum (considering the cost function is Squared Error then there is going to be only one minimum point)

# %% [markdown]
# ### for multilinear regression you try gradient descent like this:
#
# repeat{
#
#     w1 = w1 - alpha * d / d vec_w J(vec_w, b)
#     .
#     .
#     .
#     wn = wn - alpha * d / d vec_w J(vec_w, b)
#     b = b - alpha * d / d vec_w J(vec_w, b)
# }
#
# here the cost function works the same way it did in linear regression, the only difference being
# the cost function of multilinear regression deals with an entire vector of multiple features.
