# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI as ChatG
llm_gemini = ChatG(model = "gemini-flash-latest")

# %%
# test call to gemini model 
llm_gemini.invoke("What is Langchain?").content
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Projects\Training\training_env\Lib\site-packages\langchain_google_genai\chat_models.py:3071, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070 try:
# -> 3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
#
# File c:\Projects\Training\training_env\Lib\site-packages\google\genai\models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...

# %%
system_prompt = "You have to behave like a movie star who is gay and is expert in teaching AI to beginners."

user_prompt = "What is Langchain?"

from langchain_core.messages import HumanMessage, SystemMessage
import textwrap

messages = [
    SystemMessage(content=system_prompt), 
    HumanMessage(content=user_prompt)
]

response = llm_gemini.invoke(messages)

# %%
answer = textwrap.fill(str(response.content), width=100)
print(answer)

# %%
from langchain_core.prompts import PromptTemplate

# %%
prompt_template = """You have to behave like a movie star who is gay and is expert in teaching {topic} to beginners."""
prompt = PromptTemplate(
    input_variables = ["topic"], 
    template = prompt_template,
)

chain = prompt | llm_gemini
response = chain.invoke({"topic": "Explain me about how clouds are formed and how it rains through clouds in 10 lines."}).content

# %%
answer = textwrap.fill(str(response), width = 50)
print(answer)

# %%
from langchain_community.document_loaders import YoutubeLoader

# Using yt-dlp backend which is more reliable than pytube
try:
    loader = YoutubeLoader.from_youtube_url(
        "https://youtu.be/8BV9TW490nQ?si=LA8-YqlnPf8XK8ka", 
        add_video_info=True,
        language=["en"]
    )
    print("Loader created successfully")
except Exception as e:
    print(f"Error creating loader: {type(e).__name__}: {e}")

# %%
try:
    docs = loader.load()
    print(f"Successfully loaded {len(docs)} documents")
except Exception as e:
    print(f"Error loading video: {type(e).__name__}: {e}")
    docs = []

# %%
# Check if docs loaded successfully
print(f"Number of documents loaded: {len(docs)}")
if docs:
    print(f"\nFirst document metadata: {docs[0].metadata}")
    print(f"\nDocument content preview: {docs[0].page_content[:200]}...")
else:
    print("No documents loaded. The video may be restricted or unavailable.")

# %%
# Langchain Expression language and Runnables.

from langchain_core.prompts import PromptTemplate

new_prompt = """You are a school teach who teaches kids from primary section and your speciality is to teach any concpet to anyone below 5 years old.
Teach this {concept} like you would according to your assigned role."""
prompt_template = PromptTemplate(
    input_variables = ["concept"], 
    template=new_prompt
)

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

chain = prompt_template | llm_gemini | output_parser

chain.invoke({"concept": "Nuclear Fission"})
